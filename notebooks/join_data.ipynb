# %% [markdown]
# -avg wind speed for trip
# -avg wind gust
# -wind speed rising?
# -wind speed falling?
# -avg air temp
# -air temp rising?
# -air temp falling?
# -avg water temp
# -water temp rising?
# -water temp falling?
# -avg dewpoint
# -avg wind direction
# -wind direction variance
# -

# %%
- average wind
